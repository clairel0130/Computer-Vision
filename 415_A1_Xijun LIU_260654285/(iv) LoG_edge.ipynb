# %% [markdown]
# 2.2 Laplacian of Gaussian

# %% [markdown]
# 2.2 Laplacian of Gaussian edge detector

# %%
# Xijun(Claire) LIU 260654285
import cv2
import numpy as np
import matplotlib.pyplot as plt

# load the image as grayscale
img_path = "./woman.png"
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)


# apply 5x5 Laplacian filter 
laplacian= cv2.Laplacian(img, cv2.CV_64F, ksize=5)


# Initialize a 2D numpy array of same size as original image
img_output = np.zeros((img.shape[0], img.shape[1]))

for x in range(1,laplacian.shape[0]-1):
    for y in range(1,laplacian.shape[1]-1):
        if (I_lap[x,y]==0 
           or ((laplacian[x,y] * laplacian[x-1,y]) < 0)
           or ((laplacian[x,y] * laplacian[x+1,y]) < 0)
           or ((laplacian[x,y] * laplacian[x,y-1]) < 0)
           or ((laplacian[x,y] * laplacian[x,y+1]) < 0)):
            img_output[x,y] = 0
        else:
            img_output[x,y] = 255

     
# display images
plt.figure(figsize=(20, 20))
plt.subplot(131), plt.imshow(img, cmap="gray")
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(laplacian, cmap="gray")
plt.title("laplacian"), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(img_output, cmap="gray")
plt.title("Output"), plt.xticks([]), plt.yticks([])

plt.show()
